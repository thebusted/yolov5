# %%
import ultralytics
import numpy as np
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.58  Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Setup complete  (8 CPUs, 63.9 GB RAM, 98.3/111.8 GB disk)

# %%
model = YOLO('./weights/segment/car-damage.pt')

# %%
results = model('dataset/car-damage/train/images/trainScratch-44-_jpg.rf.afe952ef59132a41b7dbb49eae867bb1.jpg')
# Out:
# image 1/1 e:\AI\freerolls\dataset\car-damage\train\images\trainScratch-44-_jpg.rf.afe952ef59132a41b7dbb49eae867bb1.jpg: 640x640 4 moderates, 92.0ms
# Speed: 5.0ms preprocess, 92.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
for result in results:
    boxes = result.boxes
    masks = result.masks
    
    json_data = []
    if len(boxes) > 0:
        for mask, box in zip(result.masks.xy, result.boxes):
            points = np.int32([mask]).tolist()
            
            print(points)
# Out:
# [[[409, 278], [409, 281], [408, 282], [407, 282], [406, 283], [404, 283], [403, 284], [399, 284], [398, 285], [394, 285], [393, 286], [389, 286], [388, 287], [381, 287], [380, 288], [375, 288], [374, 289], [372, 289], [371, 290], [370, 290], [369, 291], [367, 291], [366, 292], [364, 292], [363, 293], [361, 293], [360, 294], [358, 294], [357, 295], [356, 295], [355, 296], [354, 296], [353, 297], [350, 297], [349, 298], [347, 298], [346, 299], [344, 299], [343, 300], [341, 300], [340, 301], [338, 301], [337, 302], [332, 302], [331, 303], [328, 303], [327, 304], [325, 304], [324, 305], [323, 305], [322, 306], [318, 306], [317, 307], [314, 307], [313, 308], [310, 308], [309, 309], [307, 309], [306, 310], [302, 310], [301, 311], [296, 311], [295, 312], [287, 312], [286, 313], [281, 313], [280, 314], [274, 314], [273, 315], [266, 315], [265, 316], [256, 316], [255, 317], [245, 317], [244, 318], [231, 318], [230, 319], [219, 319], [218, 320], [211, 320], [210, 321], [199, 321], [198, 322], 
# ...
